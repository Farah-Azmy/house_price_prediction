# %%
import numpy as np 
import pandas as pd 
#data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# # Reading data

# %%
df=pd.read_csv("house_data.csv")

# %%
df.head(50)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %% [markdown]
# # info about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df['date'] = df['date'].str.split('T').str[0]
df.head()
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900.0         3       1.00         1180      5650
# 1  6414100192  20141209  538000.0         3       2.25         2570      7242
# 2  5631500400  20150225  180000.0         2       1.00          770     10000
# 3  2487200875  20141209  604000.0         4       3.00         1960      5000
# 4  1954400510  20150218  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d', errors = 'coerce') 
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
pd.DataFrame({'': df.nunique().index , 'Number of unique values':  df.nunique().values})
# Out:
#                    Number of unique values
# 0              id                    21436
# 1            date                      372
# 2           price                     4028
# 3        bedrooms                       13
# 4       bathrooms                       30
# 5     sqft_living                     1038
# 6        sqft_lot                     9782
# 7          floors                        6
# 8      waterfront                        2
# 9            view                        5
# 10      condition                        5
# 11          grade                       12
# 12     sqft_above                      946
# 13  sqft_basement                      306
# 14       yr_built                      116
# 15   yr_renovated                       70
# 16        zipcode                       70
# 17            lat                     5034
# 18           long                      752
# 19  sqft_living15                      777
# 20     sqft_lot15                     8689

# %%
df=df.drop_duplicates(keep ='last',subset ='id')

# %%
df.shape
# Out:
# (21436, 21)

# %%
df['age_house']=2022-df['yr_built']

# %%
df['age_house']
# Out:
# 0        67
# 1        71
# 2        89
# 3        57
# 4        35
#          ..
# 21608    13
# 21609     8
# 21610    13
# 21611    18
# 21612    14
# Name: age_house, Length: 21436, dtype: int64

# %%
#df['age_renovated']=2022-df['yr_renovated']

# %%
df.drop(['id','date','yr_built','zipcode','lat','long'],axis=1,inplace=True)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_renovated  \
# 0     0          3      7        1180              0             0
# 1     0          3      7        2170            400          1991
# 2     0          3      6         770              0             0
# 3     0          5      7        1050            910             0
# 4     0          3      8        1680              0             0
#
#    sqft_living15  sqft_lot15  age_house
# 0           1340        5650         67
# ...

# %%
df.shape
# Out:
# (21436, 16)

# %%
(df[df.columns]==0).any()
# Out:
# price            False
# bedrooms          True
# bathrooms         True
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront        True
# view              True
# condition        False
# grade            False
# sqft_above       False
# sqft_basement     True
# yr_renovated      True
# sqft_living15    False
# sqft_lot15       False
# age_house        False
# dtype: bool

# %%
df.bathrooms.value_counts()
# Out:
# 2.50    5355
# 1.00    3795
# 1.75    3020
# 2.25    2031
# 2.00    1913
# 1.50    1430
# 2.75    1182
# 3.00     747
# 3.50     729
# 3.25     586
# 3.75     155
# 4.00     134
# 4.50      99
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 8.00       2
# 6.25       2
# 6.50       2
# 6.75       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
df.bedrooms.value_counts()
# Out:
# 3     9731
# 4     6849
# 2     2736
# 5     1586
# 6      265
# 1      194
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df.bathrooms=df['bathrooms'].transform(lambda x:x.replace(0,x.median()))

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='price',data=df)
# Out:
# <AxesSubplot:ylabel='price'>

# %%
plt.figure(figsize=(13,13))
corr = df.corr()
sns.heatmap(corr, cmap="Greens",annot=True)
plt.show()

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
df['bathrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(x=df.price,y=df.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(x=df.price,y=df.bathrooms)
plt.title("Price vs bathrooms")
# Out:
# Text(0.5, 1.0, 'Price vs bathrooms')

# %%
plt.scatter(x=df.price,y=df.bedrooms)
plt.title("Price vs bedrooms")
# Out:
# Text(0.5, 1.0, 'Price vs bedrooms')

# %%
plt.scatter(x=df.price,y=df.sqft_lot)
plt.title("Price vs sqft_lot")
# Out:
# Text(0.5, 1.0, 'Price vs sqft_lot')

# %%
plt.scatter(x=df.price,y=df.sqft_above)
plt.title("Price vs sqft_above")
# Out:
# Text(0.5, 1.0, 'Price vs sqft_above')

# %%
plt.scatter(x=df.price,y=df.sqft_basement)
plt.title("Price vs sqft_basement")
# Out:
# Text(0.5, 1.0, 'Price vs sqft_basement')

# %%
plt.scatter(x=df.price,y=df.sqft_lot15)
plt.title("Price vs sqft_lot15")
# Out:
# Text(0.5, 1.0, 'Price vs sqft_lot15')

# %%
plt.scatter(y=df.price,x=df.yr_renovated)
plt.title("Price vs yr_renovated")
# Out:
# Text(0.5, 1.0, 'Price vs yr_renovated')

# %%
plt.scatter(x=df.price,y=df.age_house)
plt.title("Price vs age_house")
# Out:
# Text(0.5, 1.0, 'Price vs age_house')

# %%
plt.scatter(y=df.price,x=df.floors)
plt.title("Price vsfloors")
# Out:
# Text(0.5, 1.0, 'Price vsfloors')

# %%
plt.scatter(y=df.price,x=df.waterfront)
plt.title("Price vswaterfront")
# Out:
# Text(0.5, 1.0, 'Price vswaterfront')

# %%
plt.scatter(y=df.price,x=df.view)
plt.title("Price vs view")
# Out:
# Text(0.5, 1.0, 'Price vs view')

# %%
plt.scatter(y=df.price,x=df.condition)
plt.title("Price vs condition")
# Out:
# Text(0.5, 1.0, 'Price vs condition')

# %%
plt.scatter(y=df.price,x=df.grade)
plt.title("Price vs grade")
# Out:
# Text(0.5, 1.0, 'Price vs grade')

# %% [markdown]
# # Detect outliers

# %%
plt.figure(figsize=(20,15))
for i,col in enumerate(set(df.columns)-{'Outcome'}):
    plt.subplot(5,7,i+1)
    sns.boxplot(data=df,x=col)
    plt.xlabel(col,fontsize=10)
    plt.xticks(fontsize=7)

# %% [markdown]
# # Delete outliers!!

# %%
def detect_outliers(df):
    outliers= pd.DataFrame(columns=["concave points_mean","perimeter_worst","perimeter_mean","area_mean","texture_worst","area_worst","concavity_worst","fractal_dimension_worst"])
    for col in list(set(df.select_dtypes(include=np.number).columns)-{'Outcome'}):
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        fence_low = q1 - (1.5*iqr)
        fence_high = q3 + (1.5*iqr)
        N_O_O = df.loc[(df[col] < fence_low) | (df[col] > fence_high)].shape[0]
                   
        df.loc[(df[col] < fence_low),col] = fence_low
        df.loc[(df[col] > fence_high),col] = fence_high
        #let's fix them
        df[col] = np.where((df[col] > fence_high) | (df[col] > fence_high),df[col].median(),df[col])
        outliers = outliers.append({'Feature': col, "NO Outliers": N_O_O ,"Handled?": df[col].all() < fence_high},ignore_index=True)
    return outliers
detect_outliers(df)
# Out:
#    concave points_mean perimeter_worst perimeter_mean area_mean texture_worst  \
# 0                  NaN             NaN            NaN       NaN           NaN
# 1                  NaN             NaN            NaN       NaN           NaN
# 2                  NaN             NaN            NaN       NaN           NaN
# 3                  NaN             NaN            NaN       NaN           NaN
# 4                  NaN             NaN            NaN       NaN           NaN
# 5                  NaN             NaN            NaN       NaN           NaN
# 6                  NaN             NaN            NaN       NaN           NaN
# 7                  NaN             NaN            NaN       NaN           NaN
# 8                  NaN             NaN            NaN       NaN           NaN
# 9                  NaN             NaN            NaN       NaN           NaN
# 10                 NaN             NaN            NaN       NaN           NaN
# ...

# %%
plt.figure(figsize=(20,15))
for i,col in enumerate(set(df.columns)-{'Outcome'}):
    plt.subplot(5,7,i+1)
    sns.boxplot(data=df,x=col)
    plt.xlabel(col,fontsize=10)
    plt.xticks(fontsize=7)

# %% [markdown]
# # Scaling data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=pd.DataFrame(sc.fit_transform(df),columns=df.columns)

# %% [markdown]
# # model

# %%
X = df.drop('price', axis=1)
y= df['price']
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, y)}')
# Out:
# Coefficients: [-2.68303494e+04  2.86746139e+04  1.36649342e+02 -2.24004404e+00
#   3.20556562e+04  1.08445875e-09 -1.49157131e-10  1.77823850e+04
#   1.09735839e+05 -3.69493009e+01 -1.13663441e+01  0.00000000e+00
#   6.80023214e+01 -1.95790238e+00  2.98449371e+03]
# Intercept: -863695.6243720154
# R^2 score: 0.6603236570146253

# %%
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(X,y, test_size = 0.30, random_state = 1)
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (15005, 15)
# (6431, 15)
# (6431,)

# %%
lin_reg = LinearRegression()
model = lin_reg.fit(X_train,y_train)
print(f'R^2 score for train: {lin_reg.score(X_train, y_train)}')
print(f'R^2 score for test: {lin_reg.score(X_test, y_test)}')
# Out:
# R^2 score for train: 0.6577542350707273
# R^2 score for test: 0.6658146870395638
